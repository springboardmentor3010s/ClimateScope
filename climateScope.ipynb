# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor3010s/ClimateScope/blob/siddhant-268/climateScope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
## the data reading part
cs = pd.read_csv('/content/drive/MyDrive/infosys project/GlobalWeatherRepository.csv')

# %%
cs.shape
# Out:
# (122576, 41)

# %%
cs.head(10)
# Out:
#                country     location_name  latitude  longitude  \
# 0          Afghanistan             Kabul     34.52      69.18
# 1              Albania            Tirana     41.33      19.82
# 2              Algeria           Algiers     36.76       3.05
# 3              Andorra  Andorra La Vella     42.50       1.52
# 4               Angola            Luanda     -8.84      13.23
# 5  Antigua and Barbuda      Saint John's     17.12     -61.85
# 6            Argentina      Buenos Aires    -34.59     -58.67
# 7              Armenia           Yerevan     40.18      44.51
# 8            Australia          Canberra    -35.28     149.22
# 9              Austria            Vienna     48.20      16.37
#
#                          timezone  last_updated_epoch      last_updated  \
# 0                      Asia/Kabul          1715849100  2024-05-16 13:15
# 1                   Europe/Tirane          1715849100  2024-05-16 10:45
# ...

# %%
cs['last_updated'] = pd.to_datetime(cs['last_updated'])
cs['sunrise'] = pd.to_datetime(cs['sunrise'])
cs['sunset'] = pd.to_datetime(cs['sunset'])
cs['moonrise'] = pd.to_datetime(cs['moonrise'])
cs['moonset'] = pd.to_datetime(cs['moonset'])
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122576 entries, 0 to 122575
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       122576 non-null  object
#  1   location_name                 122576 non-null  object
#  2   latitude                      122576 non-null  float64
#  3   longitude                     122576 non-null  float64
#  4   timezone                      122576 non-null  object
#  5   last_updated_epoch            122576 non-null  int64
#  6   last_updated                  122576 non-null  datetime64[ns]
#  7   temperature_celsius           122576 non-null  float64
#  8   temperature_fahrenheit        122576 non-null  float64
#  9   condition_text                122576 non-null  object
#  10  wind_mph                      122576 non-null  float64
#  11  wind_kph                      122576 non-null  float64
# ...

# %%
cs['sunrise'] = cs['sunrise'].astype(str)
cs['sunset'] = cs['sunset'].astype(str)
cs['moonrise'] = cs['moonrise'].astype(str)
cs['moonset'] = cs['moonset'].astype(str)
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122576 entries, 0 to 122575
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       122576 non-null  object
#  1   location_name                 122576 non-null  object
#  2   latitude                      122576 non-null  float64
#  3   longitude                     122576 non-null  float64
#  4   timezone                      122576 non-null  object
#  5   last_updated_epoch            122576 non-null  int64
#  6   last_updated                  122576 non-null  datetime64[ns]
#  7   temperature_celsius           122576 non-null  float64
#  8   temperature_fahrenheit        122576 non-null  float64
#  9   condition_text                122576 non-null  object
#  10  wind_mph                      122576 non-null  float64
#  11  wind_kph                      122576 non-null  float64
# ...

# %%
cs.describe(include ='all')
# Out:
#          country location_name       latitude      longitude      timezone  \
# count     122576        122576  122576.000000  122576.000000        122576
# unique       211           256            NaN            NaN           198
# top     Bulgaria         Kabul            NaN            NaN  Asia/Bangkok
# freq        1441           630            NaN            NaN          2298
# mean         NaN           NaN      19.191038      21.996451           NaN
# std          NaN           NaN      24.427963      65.792124           NaN
# min          NaN           NaN     -41.300000    -175.200000           NaN
# 25%          NaN           NaN       3.750000      -6.836100           NaN
# 50%          NaN           NaN      17.250000      23.316700           NaN
# 75%          NaN           NaN      40.400000      50.580000           NaN
# max          NaN           NaN      64.150000     179.220000           NaN
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
## Know going to checkout the Null, duplicate and Error values
cs.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
cs.duplicated().sum()
# Out:
# np.int64(0)

# %%
## value count _with unique_values
for i in cs.columns:
  print(i)
  print(cs[i].value_counts())
# Out:
# country
# country
# Bulgaria         1441
# Indonesia        1261
# Sudan            1258
# Thailand         1257
# Turkey           1257
#                  ...
# Saudi Arabien       1
# Bélgica             1
# Turkménistan        1
# 火鸡                  1
# Jemen               1
# Name: count, Length: 211, dtype: int64
# location_name
# location_name
# Kabul                   630
# Tirana                  630
# Andorra La Vella        630
# Luanda                  630
# Yerevan                 630
#                        ...
# Krasnyy Turkmenistan      1
# Morocco City              1
# Kiyabo                    1
# Moldova                   1
# City Of San Marino        1
# Name: count, Length: 256, dtype: int64
# latitude
# latitude
#  41.90    768
#  12.15    767
#  40.40    767
#  5.55     630
# -41.30    630
#          ...
#  10.75      1
#  4.17       1
# -7.25       1
#  42.67      1
#  59.89      1
# Name: count, Length: 396, dtype: int64
# longitude
# longitude
# ...
